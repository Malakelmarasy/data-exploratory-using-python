# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('cleaned_productsData.csv')
data
# Out:
#     Product_ID           Product_Name   Product_Category  Product_Cost  \
# 0            1          Action Figure               Toys          9.99
# 1            2         Animal Figures               Toys          9.99
# 2            3        Barrel O' Slime       Art & Crafts          1.99
# 3            4       Chutes & Ladders              Games          9.99
# 4            5       Classic Dominoes              Games          7.99
# 5            6              Colorbuds        Electronics          6.99
# 6            7               Dart Gun  Sports & Outdoors         11.99
# 7            8          Deck Of Cards              Games          3.99
# 8            9               Dino Egg               Toys          9.99
# 9           10       Dinosaur Figures               Toys         10.99
# 10          11          Etch A Sketch       Art & Crafts         10.99
# 11          12     Foam Disk Launcher  Sports & Outdoors          8.99
# ...

# %%
data.head()
# Out:
#    Product_ID      Product_Name Product_Category  Product_Cost  Product_Price
# 0           1     Action Figure             Toys          9.99          15.99
# 1           2    Animal Figures             Toys          9.99          12.99
# 2           3   Barrel O' Slime     Art & Crafts          1.99           3.99
# 3           4  Chutes & Ladders            Games          9.99          12.99
# 4           5  Classic Dominoes            Games          7.99           9.99

# %%
data.tail(20)
# Out:
#     Product_ID           Product_Name   Product_Category  Product_Cost  \
# 15          16                  Jenga              Games          2.99
# 16          17        Kids Makeup Kit       Art & Crafts         13.99
# 17          18            Lego Bricks               Toys         12.99
# 18          19             Magic Sand       Art & Crafts         13.99
# 19          20   Mini Basketball Hoop  Sports & Outdoors          8.99
# 20          21     Mini Ping Pong Set  Sports & Outdoors          6.99
# 21          22               Monopoly              Games         13.99
# 22          23         Mr. Potatohead               Toys          4.99
# 23          24               Nerf Gun  Sports & Outdoors         14.99
# 24          25            PlayDoh Can       Art & Crafts          1.99
# 25          26        PlayDoh Playset       Art & Crafts         20.99
# 26          27        PlayDoh Toolkit       Art & Crafts          3.99
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_ID        35 non-null     int64
#  1   Product_Name      35 non-null     object
#  2   Product_Category  35 non-null     object
#  3   Product_Cost      35 non-null     float64
#  4   Product_Price     35 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.5+ KB

# %%
data.shape
# Out:
# (35, 5)

# %%
data.describe()
# Out:
#        Product_ID  Product_Cost  Product_Price
# count   35.000000     35.000000      35.000000
# mean    18.000000      9.618571      14.190000
# std     10.246951      4.988727       6.153908
# min      1.000000      1.990000       2.990000
# 25%      9.500000      5.490000       9.990000
# 50%     18.000000      9.990000      12.990000
# 75%     26.500000     12.490000      19.990000
# max     35.000000     20.990000      25.990000

# %%
data.nunique()
# Out:
# Product_ID          35
# Product_Name        35
# Product_Category     5
# Product_Cost        16
# Product_Price       17
# dtype: int64

# %%
data[['Product_ID','Product_Name']]
# Out:
#     Product_ID           Product_Name
# 0            1          Action Figure
# 1            2         Animal Figures
# 2            3        Barrel O' Slime
# 3            4       Chutes & Ladders
# 4            5       Classic Dominoes
# 5            6              Colorbuds
# 6            7               Dart Gun
# 7            8          Deck Of Cards
# 8            9               Dino Egg
# 9           10       Dinosaur Figures
# 10          11          Etch A Sketch
# 11          12     Foam Disk Launcher
# 12          13       Gamer Headphones
# 13          14          Glass Marbles
# 14          15      Hot Wheels 5-Pack
# 15          16                  Jenga
# 16          17        Kids Makeup Kit
# 17          18            Lego Bricks
# 18          19             Magic Sand
# 19          20   Mini Basketball Hoop
# 20          21     Mini Ping Pong Set
# 21          22               Monopoly
# 22          23         Mr. Potatohead
# 23          24               Nerf Gun
# ...

# %%
data.iloc[0:11 , [1,3] ]
# Out:
#         Product_Name  Product_Cost
# 0      Action Figure          9.99
# 1     Animal Figures          9.99
# 2    Barrel O' Slime          1.99
# 3   Chutes & Ladders          9.99
# 4   Classic Dominoes          7.99
# 5          Colorbuds          6.99
# 6           Dart Gun         11.99
# 7      Deck Of Cards          3.99
# 8           Dino Egg          9.99
# 9   Dinosaur Figures         10.99
# 10     Etch A Sketch         10.99

# %%
data.loc[data['Product_Price']>= 20]
# Out:
#     Product_ID          Product_Name   Product_Category  Product_Cost  \
# 10          11         Etch A Sketch       Art & Crafts         10.99
# 12          13      Gamer Headphones        Electronics         14.99
# 19          20  Mini Basketball Hoop  Sports & Outdoors          8.99
# 25          26       PlayDoh Playset       Art & Crafts         20.99
# 33          34             Toy Robot        Electronics         20.99
#
#     Product_Price
# 10          20.99
# 12          20.99
# 19          24.99
# 25          24.99
# 33          25.99

# %%
data[(data['Product_Cost'] >= 10) & (data['Product_Category'] == 'Art & Crafts') ]
# Out:
#     Product_ID     Product_Name Product_Category  Product_Cost  Product_Price
# 10          11    Etch A Sketch     Art & Crafts         10.99          20.99
# 16          17  Kids Makeup Kit     Art & Crafts         13.99          19.99
# 18          19       Magic Sand     Art & Crafts         13.99          15.99
# 25          26  PlayDoh Playset     Art & Crafts         20.99          24.99

# %%
data.sort_values('Product_Category')
# Out:
#     Product_ID           Product_Name   Product_Category  Product_Cost  \
# 27          28               Playfoam       Art & Crafts          3.99
# 25          26        PlayDoh Playset       Art & Crafts         20.99
# 2            3        Barrel O' Slime       Art & Crafts          1.99
# 24          25            PlayDoh Can       Art & Crafts          1.99
# 18          19             Magic Sand       Art & Crafts         13.99
# 16          17        Kids Makeup Kit       Art & Crafts         13.99
# 10          11          Etch A Sketch       Art & Crafts         10.99
# 26          27        PlayDoh Toolkit       Art & Crafts          3.99
# 5            6              Colorbuds        Electronics          6.99
# 33          34              Toy Robot        Electronics         20.99
# 12          13       Gamer Headphones        Electronics         14.99
# 21          22               Monopoly              Games         13.99
# ...

# %%
data_groupby =data.groupby('Product_Price')
data_groupby.sum()
# Out:
#                Product_ID                                       Product_Name  \
# Product_Price
# 2.99                   25                                        PlayDoh Can
# 3.99                    3                                    Barrel O' Slime
# 4.99                   27                                    PlayDoh Toolkit
# 5.99                   15                                  Hot Wheels 5-Pack
# 6.99                    8                                      Deck Of Cards
# 7.99                   35                                      Uno Card Game
# 8.99                   31                                       Splash Balls
# 9.99                   65  Classic DominoesJengaMini Ping Pong SetMr. Pot...
# 10.99                  51                      Dino EggGlass MarblesPlayfoam
# 11.99                  12                                 Foam Disk Launcher
# 12.99                  39           Animal FiguresChutes & LaddersTeddy Bear
# ...
