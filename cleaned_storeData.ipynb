# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('cleaned_storeData.csv')
data
# Out:
#     Store_ID                     Store_Name        Store_City Store_Location  \
# 0          1       Maven Toys Guadalajara 1       Guadalajara    Residential
# 1          2         Maven Toys Monterrey 1         Monterrey    Residential
# 2          3       Maven Toys Guadalajara 2       Guadalajara     Commercial
# 3          4          Maven Toys Saltillo 1          Saltillo       Downtown
# 4          5            Maven Toys La Paz 1            La Paz       Downtown
# 5          6          Maven Toys Mexicali 1          Mexicali     Commercial
# 6          7         Maven Toys Monterrey 2         Monterrey       Downtown
# 7          8           Maven Toys Pachuca 1           Pachuca       Downtown
# 8          9  Maven Toys Ciudad de Mexico 1  Cuidad de Mexico       Downtown
# 9         10          Maven Toys Campeche 1          Campeche       Downtown
# 10        11        Maven Toys Cuernavaca 1        Cuernavaca       Downtown
# ...

# %%
data.head()
# Out:
#    Store_ID                Store_Name   Store_City Store_Location  \
# 0         1  Maven Toys Guadalajara 1  Guadalajara    Residential
# 1         2    Maven Toys Monterrey 1    Monterrey    Residential
# 2         3  Maven Toys Guadalajara 2  Guadalajara     Commercial
# 3         4     Maven Toys Saltillo 1     Saltillo       Downtown
# 4         5       Maven Toys La Paz 1       La Paz       Downtown
#
#   Store_Open_Date
# 0       9/18/1992
# 1       4/27/1995
# 2      12/27/1999
# 3        1/1/2000
# 4       5/31/2001

# %%
data.tail(20)
# Out:
#     Store_ID                     Store_Name        Store_City Store_Location  \
# 30        31  Maven Toys Ciudad de Mexico 2  Cuidad de Mexico        Airport
# 31        32        Maven Toys Hermosillo 1        Hermosillo    Residential
# 32        33         Maven Toys Monterrey 3         Monterrey        Airport
# 33        34      Maven Toys Villahermosa 1      Villahermosa       Downtown
# 34        35      Maven Toys Chilpancingo 1      Chilpancingo       Downtown
# 35        36           Maven Toys Morelia 1           Morelia       Downtown
# 36        37  Maven Toys Ciudad de Mexico 3  Cuidad de Mexico    Residential
# 37        38         Maven Toys Chihuahua 2         Chihuahua       Downtown
# 38        39            Maven Toys Xalapa 2            Xalapa       Downtown
# 39        40            Maven Toys Toluca 2            Toluca     Commercial
# 40        41        Maven Toys Hermosillo 2        Hermosillo       Downtown
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store_ID         50 non-null     int64
#  1   Store_Name       50 non-null     object
#  2   Store_City       50 non-null     object
#  3   Store_Location   50 non-null     object
#  4   Store_Open_Date  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
data.shape
# Out:
# (50, 5)

# %%
data.describe()
# Out:
#        Store_ID
# count  50.00000
# mean   25.50000
# std    14.57738
# min     1.00000
# 25%    13.25000
# 50%    25.50000
# 75%    37.75000
# max    50.00000

# %%
data.nunique()
# Out:
# Store_ID           50
# Store_Name         50
# Store_City         29
# Store_Location      4
# Store_Open_Date    50
# dtype: int64

# %%
data[['Store_Name','Store_City','Store_Open_Date']]
# Out:
#                        Store_Name        Store_City Store_Open_Date
# 0        Maven Toys Guadalajara 1       Guadalajara       9/18/1992
# 1          Maven Toys Monterrey 1         Monterrey       4/27/1995
# 2        Maven Toys Guadalajara 2       Guadalajara      12/27/1999
# 3           Maven Toys Saltillo 1          Saltillo        1/1/2000
# 4             Maven Toys La Paz 1            La Paz       5/31/2001
# 5           Maven Toys Mexicali 1          Mexicali      12/13/2003
# 6          Maven Toys Monterrey 2         Monterrey      12/25/2003
# 7            Maven Toys Pachuca 1           Pachuca      10/14/2004
# 8   Maven Toys Ciudad de Mexico 1  Cuidad de Mexico      10/15/2004
# 9           Maven Toys Campeche 1          Campeche       1/14/2005
# 10        Maven Toys Cuernavaca 1        Cuernavaca       4/19/2005
# 11          Maven Toys Chetumal 1          Chetumal        5/5/2006
# 12          Maven Toys Mexicali 2          Mexicali       8/30/2006
# ...

# %%
data.iloc[0:31 , [1,3] ]
# Out:
#                        Store_Name Store_Location
# 0        Maven Toys Guadalajara 1    Residential
# 1          Maven Toys Monterrey 1    Residential
# 2        Maven Toys Guadalajara 2     Commercial
# 3           Maven Toys Saltillo 1       Downtown
# 4             Maven Toys La Paz 1       Downtown
# 5           Maven Toys Mexicali 1     Commercial
# 6          Maven Toys Monterrey 2       Downtown
# 7            Maven Toys Pachuca 1       Downtown
# 8   Maven Toys Ciudad de Mexico 1       Downtown
# 9           Maven Toys Campeche 1       Downtown
# 10        Maven Toys Cuernavaca 1       Downtown
# 11          Maven Toys Chetumal 1       Downtown
# 12          Maven Toys Mexicali 2       Downtown
# 13        Maven Toys Guanajuato 1       Downtown
# 14  Maven Toys Tuxtla Gutierrez 1       Downtown
# 15   Maven Toys San Luis Potosi 1       Downtown
# 16            Maven Toys Toluca 1       Downtown
# 17            Maven Toys Merida 1       Downtown
# ...

# %%
data[(data['Store_City'] == 'Santiago') & (data['Store_Location'] == 'Downtown') ]
# Out:
#     Store_ID             Store_Name Store_City Store_Location Store_Open_Date
# 20        21  Maven Toys Santiago 1   Santiago       Downtown      11/23/2009

# %%
data.sort_values('Store_Open_Date')
# Out:
#     Store_ID                     Store_Name        Store_City Store_Location  \
# 3          4          Maven Toys Saltillo 1          Saltillo       Downtown
# 9         10          Maven Toys Campeche 1          Campeche       Downtown
# 13        14        Maven Toys Guanajuato 1        Guanajuato       Downtown
# 7          8           Maven Toys Pachuca 1           Pachuca       Downtown
# 8          9  Maven Toys Ciudad de Mexico 1  Cuidad de Mexico       Downtown
# 26        27            Maven Toys Oaxaca 1            Oaxaca       Downtown
# 29        30       Maven Toys Guadalajara 3       Guadalajara        Airport
# 45        46       Maven Toys Guadalajara 4       Guadalajara       Downtown
# 46        47         Maven Toys Monterrey 4         Monterrey     Commercial
# 20        21          Maven Toys Santiago 1          Santiago       Downtown
# 36        37  Maven Toys Ciudad de Mexico 3  Cuidad de Mexico    Residential
# ...
